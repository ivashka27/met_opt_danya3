# %%
import numpy as np
import method.gradient_descent as gd
import method.dichotomy_gradient as dg
import method.wolfe_gradient as wg
import plot.plotter as plotter
from random import uniform

# %%
def f(x):
    #return 10 * x[0] ** 2 + x[1] ** 2
    return 4 * x[0] ** 2 + 9 * x[1] ** 2 - 4 * x[0] * x[1] - 2 * x[0] + 12 * x[1] + 7


def grad(x):
    h = 1e-5
    return (f(x[:, np.newaxis] + h * np.eye(2)) - f(x[:, np.newaxis] - h * np.eye(2))) / (2 * h)

# %% [markdown]
# # $f(x, y) = 10x^2 + y^2$
# # $f(x, y) = 4x^2 + 9y^2 - 4xy - 2x + 12y + 7$

# %%
def print_info(name, start, points, grad_calc, func_calc):
    print("start:", start)
    print("{}:".format(name))
    print(points[-1], f(points[-1]))
    print("gradient calculations:", grad_calc)
    print("function calculations:", func_calc)


def plot_from_start(start):
    lr = 0.05
    (points1, grad_calc1, func_calc1) = gd.gradient_descent(f, grad, start, 1e-4, lr, 100000)
    print_info("gradient descent", start, points1, grad_calc1, func_calc1)

    (points2, grad_calc2, func_calc2) = dg.dichotomy_gradient(f, grad, start, 1e-4, 1e-3, 0.1)
    print_info("dichotomy gradient", start, points2, grad_calc2, func_calc2)

    (points3, grad_calc3, func_calc3) = wg.wolfe_gradient(f, grad, start, 1e-4, 1e-4, 0.9, 0.1)
    print_info("wolfe gradient", start, points3, grad_calc3, func_calc3)

    plotter.multiple_points_over_contour(points1, points2, points3, f, lr).show()

# %%
plot_from_start([-1, 2])
# Out:
# start: [-1, 2]
# gradient descent:
# [-0.09374273 -0.68749745] 2.9687500001955565
# gradient calculations: 22
# function calculations: 0
# start: [-1, 2]
# dichotomy gradient:
# [-0.09374748 -0.68749811] 2.968750000038428
# gradient calculations: 14
# function calculations: 156
# start: [-1, 2]
# wolfe gradient:
# [-0.09374605 -0.68750017] 2.968750000065164
# gradient calculations: 26
# function calculations: 26

# %%
plot_from_start([-0.5, -1])
# Out:
# start: [-0.5, -1]
# gradient descent:
# [-0.09375931 -0.68750327] 2.968750000320993
# gradient calculations: 28
# function calculations: 0
# start: [-0.5, -1]
# dichotomy gradient:
# [-0.09375296 -0.68750004] 2.9687500000346105
# gradient calculations: 18
# function calculations: 204
# start: [-0.5, -1]
# wolfe gradient:
# [-0.09375212 -0.68750318] 2.9687500000822418
# gradient calculations: 29
# function calculations: 29

# %%
plot_from_start([-0.5, 0])
# Out:
# start: [-0.5, 0]
# gradient descent:
# [-0.09375663 -0.68750233] 2.9687500001629834
# gradient calculations: 26
# function calculations: 0
# start: [-0.5, 0]
# dichotomy gradient:
# [-0.09375278 -0.68750223] 2.968750000051002
# gradient calculations: 16
# function calculations: 180
# start: [-0.5, 0]
# wolfe gradient:
# [-0.09375073 -0.6874999 ] 2.9687500000025073
# gradient calculations: 32
# function calculations: 32

# %%
plot_from_start([2, 3])
# Out:
# start: [2, 3]
# gradient descent:
# [-0.09374174 -0.6874971 ] 2.9687500002528564
# gradient calculations: 33
# function calculations: 0
# start: [2, 3]
# dichotomy gradient:
# [-0.09374637 -0.68749972] 2.968750000049506
# gradient calculations: 20
# function calculations: 228
# start: [2, 3]
# wolfe gradient:
# [-0.09374531 -0.68749955] 2.968750000081158
# gradient calculations: 34
# function calculations: 34

# %%
plot_from_start([-10, 0])
# Out:
# start: [-10, 0]
# gradient descent:
# [-0.0937571  -0.68750249] 2.9687500001864846
# gradient calculations: 36
# function calculations: 0
# start: [-10, 0]
# dichotomy gradient:
# [-0.0937524  -0.68750181] 2.968750000035108
# gradient calculations: 22
# function calculations: 252
# start: [-10, 0]
# wolfe gradient:
# [-0.09375468 -0.68750006] 2.9687500000864855
# gradient calculations: 36
# function calculations: 36

# %%
plot_from_start([0.9504983984550248, -0.766835117539493])
# Out:
# start: [0.9504983984550248, -0.766835117539493]
# gradient descent:
# [-0.09374176 -0.68749711] 2.968750000251344
# gradient calculations: 30
# function calculations: 0
# start: [0.9504983984550248, -0.766835117539493]
# dichotomy gradient:
# [-0.09374457 -0.68750034] 2.968750000126425
# gradient calculations: 17
# function calculations: 192
# start: [0.9504983984550248, -0.766835117539493]
# wolfe gradient:
# [-0.09374951 -0.6875    ] 2.9687500000009646
# gradient calculations: 36
# function calculations: 36

# %%
#generate 4 dots
dots = plotter.generate_n_dots(4)

# %%
for i in dots:
    plot_from_start(i)
# Out:
# start: [-0.21944608832996693, -0.6758603299917691]
# gradient descent:
# [-0.09375729 -0.68750256] 2.968750000196935
# gradient calculations: 25
# function calculations: 0
# start: [-0.21944608832996693, -0.6758603299917691]
# dichotomy gradient:
# [-0.09375527 -0.6874998 ] 2.9687500001157137
# gradient calculations: 15
# function calculations: 168
# start: [-0.21944608832996693, -0.6758603299917691]
# wolfe gradient:
# [-0.09375173 -0.68750146] 2.968750000021009
# gradient calculations: 27
# function calculations: 27
# start: [0.7437884168195854, 0.2589309558167199]
# gradient descent:
# [-0.09374052 -0.68749668] 2.9687500003327694
# gradient calculations: 30
# function calculations: 0
# start: [0.7437884168195854, 0.2589309558167199]
# dichotomy gradient:
# [-0.09374609 -0.68749948] 2.968750000055497
# gradient calculations: 18
# function calculations: 204
# start: [0.7437884168195854, 0.2589309558167199]
# wolfe gradient:
# [-0.09374957 -0.6874996 ] 2.9687500000014797
# gradient calculations: 36
# function calculations: 36
# start: [0.8386609373812879, 0.48553462732483244]
# gradient descent:
# [-0.0937427  -0.68749744] 2.9687500001973337
# gradient calculations: 31
# function calculations: 0
# start: [0.8386609373812879, 0.48553462732483244]
# dichotomy gradient:
# [-0.09374583 -0.6874996 ] 2.9687500000643103
# gradient calculations: 18
# function calculations: 204
# start: [0.8386609373812879, 0.48553462732483244]
# wolfe gradient:
# [-0.09374952 -0.68749951] 2.968750000002144
# gradient calculations: 36
# function calculations: 36
# start: [-0.42205571955232646, 0.8376915140839554]
# gradient descent:
# [-0.09374169 -0.68749709] 2.9687500002555076
# gradient calculations: 26
# function calculations: 0
# start: [-0.42205571955232646, 0.8376915140839554]
# dichotomy gradient:
# [-0.09374479 -0.68750068] 2.9687500001266827
# gradient calculations: 15
# function calculations: 168
# start: [-0.42205571955232646, 0.8376915140839554]
# wolfe gradient:
# [-0.09374749 -0.68749987] 2.9687500000239657
# gradient calculations: 30
# function calculations: 30

# %% [markdown]
# # LR research

# %%
lr_data = []
grad_data = []
func_data = []
start = [uniform(-2, 2), uniform(-2, 2)]
for lr in range(1, 1000, 2):
    points1, grad_calc1, _ = gd.gradient_descent(f, grad, start, 1e-4, 1 / lr, 1000)
    lr_data.append(1 / lr)
    grad_data.append(grad_calc1)
    func_data.append(min(f(points1[-1]), 4))
plotter.plot_by_two_coordinates(lr_data, grad_data, "lr", False).show()
plotter.plot_by_two_coordinates(lr_data, func_data, "lr", False, "result value")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\awishy\\venv\\lib\\site-packages\\matplotlib\\pyplot.py'>
