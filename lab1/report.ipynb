# %%
import numpy as np
import method.gradient_descent as gd
import method.dichotomy_gradient as dg
import method.wolfe_gradient as wg
import plot.plotter as plotter

# %%
def f(x):
    #return 10 * x[0] ** 2 + x[1] ** 2
    return 4 * x[0] ** 2 + 9 * x[1] ** 2 - 4 * x[0] * x[1] - 2 * x[0] + 12 * x[1] + 7


def grad(x):
    h = 1e-5
    return (f(x[:, np.newaxis] + h * np.eye(2)) - f(x[:, np.newaxis] - h * np.eye(2))) / (2 * h)

# %% [markdown]
# # $f(x, y) = 10x^2 + y^2$
# # $f(x, y) = 4x^2 + 9y^2 - 4xy - 2x + 12y + 7$

# %%
def print_info(name, start, points, grad_calc, func_calc):
    print("start:", start)
    print("{}:".format(name))
    print(points[-1], f(points[-1]))
    print("gradient calculations:", grad_calc)
    print("function calculations:", func_calc)

def plot_from_start(start):
    lr = 0.05
    (points1, grad_calc1, func_calc1) = gd.gradient_descent(f, grad, start, 1e-4, lr, 100000)
    print_info("gradient descent", start, points1, grad_calc1, func_calc1)

    (points2, grad_calc2, func_calc2) = dg.dichotomy_gradient(f, grad, start, 1e-4, 1e-3, 0.1)
    print_info("dichotomy gradient", start, points2, grad_calc2, func_calc2)

    (points3, grad_calc3, func_calc3) = wg.wolfe_gradient(f, grad, start, 1e-4, 1e-4, 0.9, 0.1)
    print_info("wolfe gradient", start, points3, grad_calc3, func_calc3)

    plotter.multiple_points_over_contour(points1, points2, points3, f, lr).show()

# %%
plot_from_start([-1, 2])
# Out:
# start: [-1, 2]
# gradient descent:
# [-1.00039308e+12  1.61880188e+00] 1.0007863205162382e+28
# gradient calculations: 6
# function calculations: 0
# start: [-1, 2]
# dichotomy gradient:
# [-2.18021347e+12  1.98676456e+00] 4.753330784875927e+28
# gradient calculations: 12
# function calculations: 132
# start: [-1, 2]
# wolfe gradient:
# [-3.2396930e-05  2.6090694e-01] 0.06808292710502477
# gradient calculations: 119574
# function calculations: 219148

# %%
plot_from_start([-0.5, -1])
# Out:
# start: [-0.5, -1]
# gradient descent:
# [-4.98885818e+11 -8.09400940e-01] 2.488870591525832e+27
# gradient calculations: 6
# function calculations: 0
# start: [-0.5, -1]
# dichotomy gradient:
# [-5.19173202e+11 -9.93047717e-01] 2.695408134742542e+27
# gradient calculations: 12
# function calculations: 132
# start: [-0.5, -1]
# wolfe gradient:
# [-1.6198465e-05 -1.3045347e-01] 0.017020731776465566
# gradient calculations: 119574
# function calculations: 219148

# %%
plot_from_start([-0.5, 0])
# Out:
# start: [-0.5, 0]
# gradient descent:
# [-4.98885818e+11  0.00000000e+00] 2.488870591525832e+27
# gradient calculations: 6
# function calculations: 0
# start: [-0.5, 0]
# dichotomy gradient:
# [-5.19173202e+11  0.00000000e+00] 2.695408134742542e+27
# gradient calculations: 12
# function calculations: 132
# start: [-0.5, 0]
# wolfe gradient:
# [-8.28777047e-11  0.00000000e+00] 6.868713936539115e-17
# gradient calculations: 78
# function calculations: 144

# %%
plot_from_start([2, 3])
# Out:
# start: [2, 3]
# gradient descent:
# [1.9903004e+12 2.4329712e+00] 3.9612956663256877e+28
# gradient calculations: 6
# function calculations: 0
# start: [2, 3]
# dichotomy gradient:
# [-1.89314927e+11  2.97880073e+00] 3.584014143951823e+26
# gradient calculations: 11
# function calculations: 120
# start: [2, 3]
# wolfe gradient:
# [6.4793860e-05 3.9136041e-01] 0.15320495330582856
# gradient calculations: 119574
# function calculations: 219148

# %%
plot_from_start([-10, 0])
# Out:
# start: [-10, 0]
# gradient descent:
# [-9.38527046e+12  0.00000000e+00] 8.808330160753061e+29
# gradient calculations: 6
# function calculations: 0
# start: [-10, 0]
# dichotomy gradient:
# [6.97769806e+11 0.00000000e+00] 4.8688270266833903e+27
# gradient calculations: 11
# function calculations: 120
# start: [-10, 0]
# wolfe gradient:
# [-3.88489242e-11  0.00000000e+00] 1.5092389090797208e-17
# gradient calculations: 91
# function calculations: 168

# %%
plot_from_start([0.9504983984550248, -0.766835117539493])
# Out:
# start: [0.9504983984550248, -0.766835117539493]
# gradient descent:
# [ 9.48013636e+11 -6.23394406e-01] 8.987298542284121e+27
# gradient calculations: 6
# function calculations: 0
# start: [0.9504983984550248, -0.766835117539493]
# dichotomy gradient:
# [ 2.17993071e+12 -7.61444565e-01] 4.752097881270415e+28
# gradient calculations: 12
# function calculations: 132
# start: [0.9504983984550248, -0.766835117539493]
# wolfe gradient:
# [ 1.14798739e-05 -9.67413261e-02] 0.0093602020474496
# gradient calculations: 119548
# function calculations: 219096

# %%
#generate 4 dots
dots = plotter.generate_n_dots(4)

# %%
for i in dots:
    plot_from_start(i)
# Out:
# start: [0.7638599770084471, 0.7610790224858308]
# gradient descent:
# [7.64698910e+11 6.15829733e-01] 5.847644226998085e+27
# gradient calculations: 6
# function calculations: 0
# start: [0.7638599770084471, 0.7610790224858308]
# dichotomy gradient:
# [1.82136376e+12 7.55721853e-01] 3.3173659375627546e+28
# gradient calculations: 12
# function calculations: 132
# start: [0.7638599770084471, 0.7610790224858308]
# wolfe gradient:
# [2.47467182e-05 9.92853995e-02] 0.00986371456253321
# gradient calculations: 119574
# function calculations: 219148
# start: [0.3480131797494044, 0.9274664987834957]
# gradient descent:
# [3.46993829e+11 7.51273346e-01] 1.204047174976742e+27
# gradient calculations: 6
# function calculations: 0
# start: [0.3480131797494044, 0.9274664987834957]
# dichotomy gradient:
# [7.23248918e+11 9.21063992e-01] 5.230889970133116e+27
# gradient calculations: 12
# function calculations: 132
# start: [0.3480131797494044, 0.9274664987834957]
# wolfe gradient:
# [1.12745586e-05 1.20991223e-01] 0.014640147251226065
# gradient calculations: 119574
# function calculations: 219148
# start: [-0.4923311680294109, -0.9210249948054443]
# gradient descent:
# [-4.91029144e+11 -7.46668086e-01] 2.4110962010711453e+27
# gradient calculations: 6
# function calculations: 0
# start: [-0.4923311680294109, -0.9210249948054443]
# dichotomy gradient:
# [-5.19868304e+11 -8.28840964e-01] 2.702630535316224e+27
# gradient calculations: 12
# function calculations: 132
# start: [-0.4923311680294109, -0.9210249948054443]
# wolfe gradient:
# [-1.59500184e-05 -1.20150907e-01] 0.014438784403486109
# gradient calculations: 119574
# function calculations: 219148
# start: [0.8270943785996838, -0.554476693950323]
# gradient descent:
# [ 8.22307550e+11 -4.48961125e-01] 6.761897075123035e+27
# gradient calculations: 6
# function calculations: 0
# start: [0.8270943785996838, -0.554476693950323]
# dichotomy gradient:
# [ 2.19249516e+12 -5.50208619e-01] 4.807035010009336e+28
# gradient calculations: 12
# function calculations: 132
# start: [0.8270943785996838, -0.554476693950323]
# wolfe gradient:
# [-6.85824127e-06 -7.21425907e-02] 0.00520502375483799
# gradient calculations: 119572
# function calculations: 219144
